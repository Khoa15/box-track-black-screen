# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread("apple.jpg")
img.shape, plt.imshow(img)
# Out:
# ((1000, 998, 3), <matplotlib.image.AxesImage at 0x192c2e32e20>)

# %%
blank_img = np.zeros((1000, 998, 3))
blank_img.shape
# Out:
# (1000, 998, 3)

# %%
x, y = 100, 200
w, h = 800, 710
startPoint = (x, y)
endPoint = (x + w, y + h)
cv2.rectangle(img, startPoint, endPoint, (0, 0, 0), 3)
plt.imshow(img)
